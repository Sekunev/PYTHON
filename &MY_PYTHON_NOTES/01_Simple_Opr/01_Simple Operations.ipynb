# %% [markdown]
# # PEP 8 kuralları;
# * 79 karakter olarak belirlenmiştir.
# * Variable lar anlamlı bir şekilde isimlendirilmelidir.
# * Herkesin anlayabileceği bir netlikte yazılmalıdır.
# * O ya da 0 kullanımda hata verebilir, L ve l kullanımda hata verebilir.
# * normal - değil alt _ kullanılır.
# * Büyük harf kullanmaması iyidir.
# * boşluk bırakılmamalı.
# * Özel karakterler kullanılmamalı.
# *

# %% [markdown]
# ##**PYTHON**
#
# > String
#
# 1.   String dataları kaç tırnak ile açılırsa o kadar tırnak ile kapatılır.

# %%
print("hello world")
print('tek tırnak ile açılırsa örnek')
print('''üç tane tırnak ile açılık kapanabilir''')
print("""çift tırnak kullanılarak string yazılabilir""")

# String içinde kesme işareti varsa çift tırnak ile aç/kapa yapılır.
print("Ali Baba'nın bir çiftliği var")  

# Birden fazla satırda alt alta string yazılacaksa """ ile aç/kapa yapılır.
print("""Çiftliğinde inekleri var  
meee meee diye bağırır
Ali Baba'nın çiftliğide""")  

# Satır arası boşluk bırakmak istiyorsak...
print()

# Yan yana output alabilmek için değerleri , ile ayırarak yazmamız gerekir.
# Genel Kural!! Virgülllerden önce boşluk gelmez. virgülden sonra bir boşluk gelir.
print("ali", 'veli', 49, 50)

# %% [markdown]
# > Integer ve Float

# %%
# Sayılar tırnak işareti kullanılmadan yazılır.
print(8)
print(5.8)  # Ondalıklı sayılar nokta işateri ile ayrılır
print(5.7, 6.9, 1, 'Clarusway')  # Virgül konularak yan yana değer alınabilir.
# Out:
# 8
# 5.8
# 5.7 6.9 1 Clarusway

# %% [markdown]
# > Yazım kuralları

# %%
foo = (2,)  # Virgülden sonra parantez kapanacaksa boşluk konulmaz
 x, z: k;   # Virgül, iki notta veya noktalı virgülden önce boşluk bırakılmaz.
print('soul of python')  # Fonksiyonlardan sonra boşluk gelmez.(yani parantez açmadan önce)

x = 3 + 8  # +, -, *, == Gibi operatörlerden önce/sora birer boşluk olur.
y == 5 * 8    

or for not and   # Bu gibi operatörlerin öncesi/sonrası boşluk gelir.

# Tek başına 'l' ve 'O' harfi kullanılmaz. '1've '0(sıfır)' rakamı ile karıştırmamak için.

# %%
# 3 satır çıktı verir.
print("""This     
is
great""")
# Out:
# This
# is
# great

# %% [markdown]
# > Yorum yazım kuralları

# %%
print('Hatırlatma ödevlerin son teslim tarihi 6 Mayıs')  # Dikkat
print("""Yorum işareti #'dan önce iki sonra bir boşluk bırakılır.
Yorumlar tutarlı, gerekli ve güncel olmalı.
Toplu comment almak için, satırlar seçilmeli ce ctrl+ /(bölme) tuşlarına basılmalı""")
# Out:
# Hatırlatma ödevlerin son teslim tarihi 6 Mayıs
# Yorum işareti #'dan önce iki sonra bir boşluk bırakılır.
# Yorumlar tutarlı, gerekli ve güncel olmalı.
# Toplu comment almak için, satırlar seçilmeli ce ctrl+ /(bölme) tuşlarına basılmalı

# %% [markdown]
# > Variable (Değişkenler)

# %%
isim = 'Michael'  # Değikenlerin bir adı vardır. Örn: 'isim'

yaş = 49  # Değişkenlere bir değer atanır. Örn '49'

print(isim, yaş)  # Değişken isimleri bu şekilde 

math_score = 30  # Değişkene verilen isim çok uzun olmamalı
                 # Kelimeleri çağrıştırmalı, karışık olmamalı
                 # Kelimeler sadece alt çizgi _ ile ayrılmalı
 # if, or, and gibi Python keywords'lerini değişken olarak yazamayız.
 # değişken isimleri Rakam veya Özel harflerle başlayamaz '!,@.$'


x = 2
y = None  # Daha sonra değer koymak istediğimiz değişkene ' None ' değerini verebiliriz.
z = 9

# Büyük/ küçük harflere dikkat edilmeli. Yazım yanlışı yapılmalı.

# %%
a, b, c = 5, 6, 8  # Yan yana yazılan değişkenlere yan yana değer verebiliriz
x = y = z = 'clarusway' # Aynı değeri verebiliriz

a = 11  # Bu gibi bir örnekte output alınırken yazılan en son değer kabul görür
b = 22
c = 44

a = 33  # a için en son yazılan değer
b = 55  # b için en son yazılan değer
c = a  # c zten a'ya eşit 
print(a, b, c)  # Gerisini biliyorsunuz zaten
# Out:
# 33 55 33

# %%
jan = marc = may = july = aug = oct  = dec = 31  # Örnek
feb = 28
apr = june = sept = nov =30
print(jan, feb, marc, apr, may, june, july, aug, sept, oct, nov, dec)
# Out:
# 31 28 31 30 31 30 31 31 30 31 30 31

# %% [markdown]
# > Data Types

# %%
# type fonksiyonu kullanarak değerin tipini bulabiliriz
type('ali veli')  # String değerler

type(3)  # Integer veri tipi

type(8.7)  # Float veri tipi

# %%
x = 547
str(x)  # 547 değerini string yapar

y = 4.1
int(y)  # 4.1 değerini integer yapar

z = 7
float(z)  # 7 değerini float yapar 

#Complex veri türü de var ama kullanmıyoruz

t = 8
bool(t == 8)  # Boolean fonksiyonu sadece  'True' mu 'False' cevabını verir.

# %% [markdown]
# Data Types and Useful Operations
# "Sİmple Operations"

# %%
a = -3
print(-a)
# Out:
# 3

# %%
print(9//4) # bölümü verir.
print(9/4) # böler.  #/ işleminin sonucu floatdur. #bir işlemde bölme işlemi varsa veya sayılardan biri flaot ise sonuç her zaman flaot dur.
print(49%5) # kalanı verir. bir sayının bölünebilirliğini bulmaya yarar.
print(45864629%12)
# Out:
# 2
# 2.25
# 4
# 5

# %%
a = (1 + 3) ** (2 ** (1 * 2 / 2) / 2)  # her zaman işlem önceliği vardır.
                                       # önce parantez içi
                                       # ** üst alma
                                       # - negatif sayılar 
                                       # * ve /
                                       # + ve - 
print(a)
# Out:
# 4.0

# %%
print((3+2)+(1.8+3.2)*2 ) # İntigerların toplamı integer, int ile Float toplamı float'dır.
# Out:
# 15.0

# %%
print((3+2)+(2+3)**0.5) # İntigerların toplamı integer, int ile Float toplamı float'dır.
# Out:
# 7.23606797749979

# %%
kapı1, kapı2 = 42, 8
kapı3 = kapı2-kapı1
print((kapı3+34+8)//2)   ,  #// işleminin sonucu int dır # % (modülus) kalanı verir.
print(8/2)              # / varsa Flaot sonuç çıkar.
# Out:
# 4
# 4.0

# %%
print(102%25) # % operatörü bölünen sayıdan kalanı yazdırır
print(102//25)
print(2**3) # ** kuvvetini yazdırır.
print(25**0.5) # karekökü ifade eder. kare kök 1/2 dir. dolayısıyla sonuç flaotdur. Bölme işlemi işin içine girdiği için.
print('bu işlemin sonucu (21+8) sum:', 21+8)
# Out:
# 2
# 4
# 8
# 5.0
# bu işlemin sonucu (21+8) sum: 29

# %%
pi = 3.14
r = 5
area = pi * r**2
print(area)
# Out:
# 78.5

# %% [markdown]
# # Operations with 'print( )' **Function**

# %%
print('İ', end='')  # end=' ' bu fonksiyon çıktıların alt alta değilde yan yana olmasını sağlıyor. \n 
print('will say', end='    ') # tırnak içerisinde ne kadar boşluk  konulursa çıktıda da o kadar çok boşluk oluşuyor.
print('İ missed you',end=' ')
print('to my mother')
# Out:
# İwill say    İ missed you to my mother

# %%
print('ali', end = " ")
print('veli')
# Out:
# ali veli

# %%
print('ben' +  'kahve', 'içeceğim', sep='                      ')  # sitring valu lerin arasına + konduğunda boşluk oluşmuyor. 
print('ben' 'kahve', 'içeceğim', 3, 4, sep=' + ') # sep=' + ' bu işlev aralara operatör boşluk yerleştirmeye yarıyor.
'mr'
3.14
74
print(type('mr'), type(3.14), type(74), sep="\n")
print(type('mr'), type(3.14), type(74))
# Out:
# benkahve                      içeceğim
# benkahve + içeceğim + 3 + 4
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'str'> <class 'float'> <class 'int'>

# %%
x = 5 
print("x'in değeri           :", x)

x += 2
print("x'in 2 fazlası        :", x,"\n")  # ? çıktı neden 2 satır aşağı indi. Bir satır'\n' den dolayı 1 satır ise Print in yeni bir satırda olması nedeniyle.
print("x'in 2 fazlası        :", x,"\n")  # "\n" alt satıra geçmeyi sağlar. Sep ile kullanıldığında değişkenleri alt satıra indirmeye yarar.
y = 10 
y -= 2
y *=2
print("y'nin değeri          :", y)
print("y'nin 2 eksiği        :", y)
print("y'nin 2 katı        :", y)
# Out:
# x'in değeri           : 5
# x'in 2 fazlası        : 7
#
# x'in 2 fazlası        : 7
#
# y'nin değeri          : 16
# y'nin 2 eksiği        : 16
# y'nin 2 katı        : 16

# %%
x = 10  #  = işareti öncesi matematik operatörleri eşitliğin sagına yazılan sayı kadar değişkene işlem uygular.

x +=3 #  -----> x = x + 3
x -=3
x *=2
x /=2
x //=2
x %=2
x +=1
x **=2

print(x)
# Out:
# 4.0

# %%
'mr'
3.14
74
print(type('mr'), type(3.14), type(74), sep="\n")
print(type('mr'), type(3.14), type(74), "\n")  # burada "\n" itemleri yazmaya müteakip alt satıra geçiyor.
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'str'> <class 'float'> <class 'int'>

# %% [markdown]
# # **Escape** **Sequences**

# %%
#   Hatırlayalım. Ne dedik? Ters slash 2 şey yapıyordu. Bazı normal karakterlere sihir (özellik) katıyordu. (n,b,t gibi) 
#   Sihirli (özel) karakter varsa onun sihrini kaldırıyordu.
print('C:\nov\num.txt') # "\n" yeni satır Dikkat!!!!
print("one", "two", "three", sep="\t")  #  "\t" value'ler arasında tab (boşluk) bırakmak için kullanılır.
print('we ', '\bbold', '\burn') # "\b" kendinden önceki karakteri siler.
print('Hi \r there')  # satır başı yapar.
print('Hi \\r \\there')  # satır başı yapar.
# Out:
# C:
# ov
# um.txt
# one	two	three
# urn
#  there
# Hi \r \there

# %%
print("ali \nveli")
# Out:
# ali
# veli

# %%
print("""ali 
veli
asd""")  # Üç tırnak kullanılarak oluşturulan dizeler için yeni satırlar otomatik olarak eklenir. \n ye gerek yok.
# Out:
# ali
# veli
# asd

# %%
print('it\'s funny to learn payton')  # tek tırnak içinde tek tırnak hata vermesini engellemek için "\" metodu kullanılır
                                      # ancak uzun stringlerde dikkat hata verebilir. hata vermemesi için; " ","" ""
# Out:
# it's funny to learn payton

# %% [markdown]
# # **The Strength of Strings in Python**  [number] >> index'leme [start:stop:step] >> slice'lama

# %%
fruit = 'Orange'  # String elemanlarına(karakterlerine) ayrılabilir. 
print('Kelime                    : ' , fruit)
print('Birinci Harfi             : ' , fruit[0])     # köşeli parentezle. İndex leme.Birinci Harfi
print('İkinci Harfi              : ' , fruit[1])
print(                                 fruit[:])     # hepsini yazar
print('3 le 5 arası Harfi        : ' , fruit[2:5])   # Bunun adı slayslama. 3 le 5 arası Harfi (!Unutmayın, bir dizenin numaralandırılması sıfırdan başlar)
print('3 ten sonraki Harfleri    : ' , fruit[2:])    # 3 den sonraki Harfleri 
print('6 dan önceki harfleri     : ' , fruit[:5])    # 5 ten önceki harfleri
print('2şer atlama               : ' , fruit[::2])   # 2 şer atlayarak harfler
print('Son üç harfi              : ' , fruit[-3:])   # Son üç harfi
print('Tersten yazılışı          : ' , fruit[::-1])  # Tersten yazılış
print('Fruit ', len(fruit), ' karakterlidir.')       # len() kaç karakterli olduğunu bulmaya yarar.# integer ve float değerlerde len fonksiyonu çalışmayacaktır.
print(fruit[1:-2])                                   # bu şekilde farklı kullanımları da var. İnceleyiniz...
print(fruit[2:5:-1])                                 # soldan sağa okuma yapmamız gerekiyor, ama -1 olduğu için boş sonuç verecek
print(fruit[-4])
fruit[2]
fruit[0:3]
# Out:
# Kelime                    :  Orange
# Birinci Harfi             :  O
# İkinci Harfi              :  r
# Orange
# 3 le 5 arası Harfi        :  ang
# 3 ten sonraki Harfleri    :  ange
# 6 dan önceki harfleri     :  Orang
# 2şer atlama               :  Oag
# Son üç harfi              :  nge
# Tersten yazılışı          :  egnarO
# Fruit  6  karakterlidir.
# ran
#
# a
# 'Ora'

# %%
print(fruit[2:5:-1])
print(fruit[5:2])

# %% [markdown]
# # String Formatting with Arithmetic **Syntax**

# %%
fruit = 'Orange'
fruit += ' Banana'   # "+=" ile önceki değişken değeri ile birleştirdi.
fruit += ' apricot'

print(fruit)

print('clarus' + 'way')
print(3*'way')
print(*'Clarusway')  # Boşluk görünümlü hale getiriyor.
sonuç = str(11**2) + "121" # + işareti değerleri tamamen yan yana birleştirir. String'te Toplama yapmaz
sonuç
# Out:
# Orange Banana apricot
# clarusway
# waywayway
# C l a r u s w a y
# '121121'

# %%
a = 2   # 
b = 3
a += b
a
# Out:
# 5

# %% [markdown]
# # String Formatting with '%' **Operator**

# %%
ifade = 'benim %d %s ve %.2f erkek kardeşim var' % (4, 'çocuğum', 5) 
# ' %s' sözdiziminde : s'string' anlamına gelir.
# ' %.1f' sözdiziminde : f'float' anlamına gelir. Bu örnekte noktadan sonra 2 basamak.
# ' %d' sözdiziminde : d'integer' anlamına gelir.

print(ifade)
# Out:
# benim 4 çocuğum ve 5.00 erkek kardeşim var

# %%
cümle = "kahraman maraşa gideceğiz." # ilk 11 karakterini alıyoruz
print('%.11s' % cümle)
# Out:
# kahraman ma

# %%
print('%(kilogram)d kilo %(meyve)s aldım' %{'kilogram': 26, 'meyve': 'muz'})
# Out:
# 26 kilo muz aldım

# %% [markdown]
# # **String Formatting with 'string.format()' Method**

# %%
print("{0}{1}{0}".format("abra", "cad"))
# Out:
# abracadabra

# %%
str="{c}, {b}, {a}".format(a=5, b=9, c=7)
print(str)
# Out:
# 7, 9, 5

# %%
# 1. yol
meyve = 'Kayısı'
sebze = 'Samırsak'
miktar = 4
asd = 5

print('aldığım {} {}, {} {} kilo'.format(meyve, miktar, sebze, asd))
# 2. yol
print('aldığım {3} {2}, {1} {0} kilo'.format(meyve, miktar, sebze, asd)) #  index numarası vererek de sonuç alırız. index 0 , 1, 2 şeklinde devam eder.
"aldığım {} {}, {} {} kilo".format(meyve, miktar, sebze, asd)
# Out:
# aldığım Kayısı 4, Samırsak 5 kilo
# aldığım 5 Samırsak, 4 Kayısı kilo
# 'aldığım Kayısı 4, Samırsak 5 kilo'

# %%
# 3. yol
şehir='İstanbul'  # değişkenleri formatın içinde tanımlarsak yer değişikliği yapabiliriz.
özellik='pahalı'
Ülke='türkiye'
print('{şehir} {Ülke}\'nin en güzel ve {özellik} şehirlerindendir.'.format(şehir='İstanbul', Ülke='türkiye', özellik='pahalı'))
# 4. yol
print('{} {}\'nin en güzel ve {} şehirlerindendir.'.format('İstanbul', 'türkiye', 'pahalı'))
# Out:
# İstanbul türkiye'nin en güzel ve pahalı şehirlerindendir.
# İstanbul türkiye'nin en güzel ve pahalı şehirlerindendir.

# %%
print("{3} {1} {2} {4} {5} {0}".format('kişiyiz', 'ailede', 'ben', 'bizim', 'dahil', 5)) # Numaralandırmanın adı index numarasıdır.
# Out:
# bizim ailede ben dahil 5 kişiyiz

# %%
a = 3
b = 5
print("biz {} kişiydik, {} kişi daha geldi, {} kişi olduk ".format(a, b, a+b))   # *, ** gibi diğer aritmetik işlemler de yapılabilir.
# Out:
# biz 3 kişiydik, 5 kişi daha geldi, 8 kişi olduk

# %%
text = "{:.2f}, {:.3f}, {:.4f}".format(3.145, 5.25456, 6.12254)  # (:) sihir katar. flaot da . dan sonra kaç rakam olması gerektiğini belirleriz.
text
# Out:
# '3.15, 5.255, 6.1225'

# %%
text = "{:.2}, {:.3}, {:.4}".format(3.145, 5.26756, 6.12254) # . sonrasını yuvarladı
text
# Out:
# '3.1, 5.27, 6.123'

# %%
text = "{:.2s}, {:.3s}, {:.4}".format("s3.d145", "l525456", "c6.12v254")  # string de ise baştan itibaren sayarak alır. "s" yazmasak ta sıkıntı olmaz.
text
# Out:
# 's3, l52, c6.1'

# %%
text = "{:>10}".format("ali") # 10 karakter sağa yasladı. < işareti ile yapsaydık sola yaslardı.
print(text)
len(text)
# Out:
#        ali
# 10

# %%
text = "{:<20}".format("güzellik")  # dikkat "" içi toplam 20 karakter. Defaultu < işaretidir.
# text = "{:20}".format("güzellik")
text
# len(text)
# Out:
# 'güzellik            '

# %%
text = "{:^20}".format("dürüstlük")  # ^ortaladı. 20 karakterin içine.
text
# Out:
# '     dürüstlük      '

# %%
text = "{:30.5}".format("1234566789asdfgh")  # 30 karakterlik bir string havuzunun içine format taki stringin ilk 5 karakterini yerleştirdi. 
text
# Out:
# '12345                         '

# %%
print(format("Welcome",  "10s"), end = '*')  #    format() metodu ikinci yazılan numara sayısı karaktere ilk ifadeyi yerleştirir.
print(format(111,  "6d"), end =  '*')
print(format(924.656,  "8.2f"))
# Out:
# Welcome   *   111*  924.66

# %%
satış_değeri= 45.986    # round() metodu en yakın değere yuvarlama yapar.
round(satış_değeri)
# Out:
# 46

# %% [markdown]
# # **String Formatting with 'f-string'**

# %%
meyve = 'portakal'
sebze = 'havuç'
Ağırlık = '6'
output = f"Aldığımız {meyve} ve {sebze.capitalize()}ların toplam ağırlığı {Ağırlık} kilo"
print(output)

result = f"{4 * 2}"
print(result)
# Out:
# Aldığımız portakal ve Havuçların toplam ağırlığı 6 kilo
# 8

# %%
adı = "adil"
mesleği = "teknisyen"
sektör = "tekstil"
mesaj = f"merhaba {adı}. " \
    f"sen {mesleği}\'liğe devam ediyormusun? " \
    f"{sektör} sektöründeydin değil mi?"

mesaj1 = ( 
    f"merhaba {adı}. "
    f"sen {mesleği}\'liğe devam ediyormusun? "
    f"{sektör} sektöründeydin değil mi?"
)
print(mesaj)
print(mesaj1)
# Out:
# merhaba adil. sen teknisyen'liğe devam ediyormusun? tekstil sektöründeydin değil mi?
# merhaba adil. sen teknisyen'liğe devam ediyormusun? tekstil sektöründeydin değil mi?

# %% [markdown]
# And - Or - Not Kavramları
# Boolenan **Operations** :False dışında; None, 0, 0.0, 0j gibi sayısal sıfırlar, "", [], {}, gibi içi boş parantezler False anlamına gelir. Bunlar dışında kalan değerler True olarak kabul edilir. Öncelik sırası NOT, AND, OR şeklindedir.

# %%
 20!=30 # (!=)iki değeri karşılaştırır ve soldaki değer sağdaki değere eşit değilse True döner  Aksi halde False döner.
# Out:
# True

# %%
20==30  # (=) iki değeri karşılaştırır ve soldaki değer sağdaki değere eşitse True döner Aksi takdirde False döner. 
        # (!=),(=),(<),(>),(>=),(<=) Bu karşılaştırma işleçleri iki değeri karşılaştırır ve bir boole değeri döndürür
# Out:
# False

# %%
x = True and False and True  # and soldan sağa doğru okuma yapar. ne zaman ilk False değerini görürse, o degeri döndürür.
print(x)  
y = True and True and True  # eğer bütün değerler true ise son true değeri okur 
print(y)  

z = False or True or False  # or soldan sağa okuma yapar ve ne zaman ilk true değerini görürse o değer döner.
print(z)
False or False or False  # eğer bütün değerler False ise son false değeri okur
k = 0 or None or "" or {}  # hiç true değer yok, en sondaki false ( "" ) değerini okuyacaktır
print(k)

m = not True  # not yanındaki değeri True ise false, false ie true yapar
n = not False 
print(m, n)
# Out:
# False
# True
# True
# {}
# False True

# %%
text = True or False and not True  # Not,  and ve or  arasında işlem sırası vardır.
print(text)                        # 1. not 
                                   # 2 and 
print()                                 # 3 or 
            # Örnekler                       
print(2 and "hello")  # iki değer de true son değeri okur
print([] and "be happy")  # ilk değer false, bunu okur
print(None and ())  # iki değer de false ilk değeri okur
# Out:
# True
#
# hello
# []
# None

# %% [markdown]
# olmazsa olmaz dediğimiz koşullarda 'and' ile bağlanır fark etmez dediğimiz koşullar 'or' ile bağlanır

# %%
kadayıf = True  # olmazsa olmaz
# iç ---> olmazsa olmaz
fındık = False  # fark etmez
fıstık = False  # fark etmez
ceviz = False  # fark etmez

#şerbet ---> olmazsa olmaz
su = True
şeker = True
yumurta = True

# %%
yedim = kadayıf and (şerbet) and (iç) and yumurta

# %%
yedim = kadayıf and (su and şeker) and (fındık or fıstık or ceviz) and yumurta
print(yedim)
# Out:
# False

# %% [markdown]
# Main String **Operations**

# %%
e_mail = 'www.alibaba.com'      #Formül sözdizimleri şunlardır:
                                # string.startswith(prefix[, start[, end]])
                                # string.endswith(suffix[, start[, end]])
print(e_mail.endswith('.com'))    # Sonunda .com arar.
print(e_mail.startswith('http:'))  # başında 'http:' arar.
print(e_mail.startswith('w', 2, 5)) # seçilen dilim '2-5' başında w arar.
# Out:
# True
# False
# True

# %%
sentence = "I live and work in Virginia"

print(sentence.upper())     # str.upper() dizenin tüm karakterlerini büyük harfe dönüştürür.

print(sentence.lower())     #str.lower()dizenin tüm karakterlerini küçük harfe dönüştürür.

print(sentence.swapcase())  #str.swapcase()büyük harfi küçük harfe çevirir ve bunun tersi de geçerlidir.

print(sentence.capitalize())  # str.capitalize()dizenin ilk karakterini büyük harfe ve geri kalanını küçük harfe değiştirir.

print(sentence.title())  # str.title()her kelimenin ilk karakterini büyük harfe dönüştürür.

print(sentence.count("a"))  # str.count() cümledeki tırnak içerisindeki eleman sayısını sayar ve yazdırır.

print(max(sentence))  # max() en büyük değeri yazar.

print(sentence.find("a"))  # find("") karakterin stringde hangi indexte olduğunu yazdırır.

print("Virginia" in sentence)  # Sentence içerisinde Virginia varmı? sentence yerine " " içerisinde str de yazılabilirdi.

changed_sentence = sentence.replace("i", "+")  #str.replace(old, new[, count]) eskinin tüm oluşumlarını yeniyle değiştirir.
print(changed_sentence)  

print(sentence)  # note that, source text is unchanged

print(sentence.find("a"))  # find("") karakterin stringde hangi indexte olduğunu yazdırır.
print(sentence.index('a'))

# %% [markdown]
# index() ile find() arasındaki fark tablosu
# index()	                                                    find()
# Alt dize bulunamazsa bir istisna döndürür	                Alt dize bulunamazsa -1 döndürür
# Alt dizenin varlığından emin değilseniz kullanılmamalıdır.	Bir alt dizenin varlığından emin olmadığınızda kullanmak için uygundur.
# Bu, dizilere, listelere ve demetlere uygulanabilir.	        Bu yalnızca dizelere uygulanabilir
# Koşullu ifade ile kullanılamaz	                            Bir alt dize bulunursa, bir ifadeyi yürütmek için koşullu ifadeyle birlikte kullanılabilir.

# %%
sentence = "I live and work in Virginia"  # içersinde yoksa -1 döndürür.
print(sentence.find("j"))
# Out:
# -1

# %%
sentence = "I live and work in Virginia"
print("inVirginia" in sentence)
# Out:
# False

# %% [markdown]
# Bir metindeki harflerin büyük mü küçük mü olduğunu da .isupper() veya islower() ile sorgularız.

# %%
print("abbabbabbabb".count('bb', 8))  # 8. index den sonra kaçtane 'bb' var onu sayar.
# Out:
# 1

# %%
print("abbabbabbabb".count('bb', 8, 10))  # 8 ile 10 index leri arasında kaçtane 'bb' var onu sayar.
# Out:
# 0

# %%
x = input("sorgulamak istediğiniz cümleyi yazınız; ")
a = (x.upper())
print(a)
print(x.isupper())  # bu sorgulamayı şu şekilde de yapabiliriz. "değer.upper() == değer" 
a.isupper()
# Out:
# sorgulamak istediğiniz cümleyi yazınız; dbbrnn
# DBBRNN
# False
# True

# %%
nx = "In God wee Trust"    #str.replace(old, new[, count]) eskinin tüm oluşumlarını yeniyle değiştirir. Coun yerine yazılan sayı kaç tane e nin değiştirilmesinin istendiğidir.
x1 = nx.replace("e", "l", 1)
print(nx.replace("e", " ", 1))
print(x1)
# Out:
# In God w e Trust
# In God wle Trust

# %%
sentence = "I live and work in Virginia"
swap_case = sentence.swapcase()
print(swap_case)
print(swap_case.capitalize())
# Out:
# i LIVE AND WORK IN vIRGINIA
# I live and work in virginia

# %% [markdown]
# # Editing a **String**

# %%
cümle = "   Bayramın ilk günü   nü"  
print(cümle.strip())              #str.strip(): her iki taraftaki tüm boşlukları (veya belirtilen karakterleri) kaldırır.
print(cümle.rstrip('mü'))             #str.rstrip() : removes spaces (or specified characters) from the right side
print(cümle.lstrip())             #str.lstrip(): sol taraftaki boşlukları (veya belirtilen karakterleri) kaldırır.
# Out:
# Bayramın ilk günü   nü
#    Bayramın ilk günü   n
# Bayramın ilk günü   nü

# %%
Bayram = "Ramazan"
print(Bayram.strip("Rn"))  # strip fonksiyonu başta ve sonda istenen karakterleri kaldırdı. Tüm kombinasyonlar, yani r, n, rn seçeneklerinin hepsi.
print(Bayram.strip("Rna"))
print(Bayram.rstrip("anaz"))  # rstrip sağdaki karakteri kaldırdı
print(Bayram.lstrip("rR")) # lstrip soldaki karakteri kaldırdı.
print(Bayram.strip("naR"))
# Out:
# amaza
# maz
# Ram
# amazan
# maz

# %%
my_string = "In 2010, someone paid 10k Bitcoin for two pizzas."

print(my_string.split(sep='a', maxsplit=3))
# Out:
# ['In 2010, someone p', 'id 10k Bitcoin for two pizz', 's.']

# %%
my_string = "In 2010, someone paid 10k Bitcoin for two pizzas."

print(my_string.split('a', 3))
# Out:
# ['In 2010, someone p', 'id 10k Bitcoin for two pizz', 's.']

# %%
x = "bu akşam python dersi var"
b = x.split(" ")                # split metodu uygulandığı stringin " " içerisinde belirtilen karakterlerden parçalara böldü.
print(b)
c = " ".join(b)                 # .join()metodu bir ittrable (str) ye uygulandı "" içerisinde belirtilen karakterlerden parçaları birleştirerek str oluşturdu.
print(c)
print(type(b))                  # split metodu uygulandığı stringi list türüne çevirdi.
print(type(c))
# Out:
# ['bu', 'akşam', 'python', 'dersi', 'var']
# bu akşam python dersi var
# <class 'list'>
# <class 'str'>

# %%
string = "Her gün, her hafta, bilgime yeni bilgiler katıyorum, bu beni çok motive ediyor."
a = string.split()
print(a)
b = chr(37).join(a)  # chr(37)= %
print(b)
c = b.split(',%')
print(c)
d = chr(35).join(c)  # chr(35)= #
print(d, type(d))
# Out:
# ['Her', 'gün,', 'her', 'hafta,', 'bilgime', 'yeni', 'bilgiler', 'katıyorum,', 'bu', 'beni', 'çok', 'motive', 'ediyor.']
# Her%gün,%her%hafta,%bilgime%yeni%bilgiler%katıyorum,%bu%beni%çok%motive%ediyor.
# ['Her%gün', 'her%hafta', 'bilgime%yeni%bilgiler%katıyorum', 'bu%beni%çok%motive%ediyor.']
# Her%gün#her%hafta#bilgime%yeni%bilgiler%katıyorum#bu%beni%çok%motive%ediyor. <class 'str'>

# %%
chr(37)
# Out:
# '%'

# %%
ıvırzıvır = "ali-deli-veli".split("-")

ıvırzıvır
# Out:
# ['ali', 'deli', 'veli']

# %%
a = 'av'
b = tuple(a) 
print(('a') in ('a', 'v', 'z'))
b
# Out:
# True
# ('a', 'v')

# %%
tuple(a)
# Out:
# ('a', 'v')

# %%
width = 15
print('HackerRank'.ljust(width,'-')) # ikinci parametre '-' tek karakteli olmalıdır.
print('HackerRank'.ljust(15))  # defaul'tu boşluktur. 
# HackerRank----------
# Out:
# HackerRank-----
# HackerRank

# %%
width = 20
print('HackerRank'.rjust(width,'-'))
# HackerRank----------
# Out:
# ----------HackerRank

# %%
width = 20
print('HackerRank'.center(width,'-'))
# HackerRank----------
# Out:
# -----HackerRank-----

# %%
m, n = map(int, input('arası boşluklu 2 sayı giriniz: ').split())

for i in range(1, m, 2):
  print(str('.|.'*i).center(n, '-'))
print('WELCOME'.center(n, '-'))
for i in range(m-2, 0, -2):
  print(str('.|.'*i).center(n, '-'))
# Out:
# arası boşluklu 2 sayı giriniz: 9 28
# ------------.|.-------------
# ---------.|..|..|.----------
# ------.|..|..|..|..|.-------
# ---.|..|..|..|..|..|..|.----
# ----------WELCOME-----------
# ---.|..|..|..|..|..|..|.----
# ------.|..|..|..|..|.-------
# ---------.|..|..|.----------
# ------------.|.-------------

# %%
def solve(s):
  for i in s.split():
    s = s.replace(i, i.capitalize())
  return s
solve('ali demir')
# Out:
# 'Ali Demir'

# %%
import textwrap

def wrap(string, max_width):
    # Text Wrap in Python - HackerRank Solution START
    return textwrap.fill(string, max_width)
    # Text Wrap in Python - HackerRank Solution END
print(wrap('ABCDEFGHIJKLIMNOQRSTUVWXYZ', 4))
# Out:
# ABCD
# EFGH
# IJKL
# IMNO
# QRST
# UVWX
# YZ

# %%
x, y = [1, 2]
# x = y  # Bu iki satırda x ve y nin değerleri eşitlenmiş oldu.
# y = x
x, y = y, x # burada aynı anda atama yapıldığı için değerler farklı çıkar.
print(x)
print(y)
# Out:
# 1
# 2
