# %% [markdown]
# 1)  A jumbled list is given whose elements are consecutive numbers. Write python code that outputs even numbers of missing numbers that are between the smallest element and the largest element of the list, but not shown in the list.
#
# Input
#
# liste = [48, 10, 11, 21, 36, 5, 6, 52, 28, 29, 53, 54, 45, 19, 20, 47, 55, 39, 41, 7, 9, 17, 26, 27, 42, 22, 37, 51, 46, 18, 44, 30, 34, 13, 15, 35, 33, 16, 50, 24]
#
# Expected Output:
# 8 12 14 32 38 40
#
# ----------------------------------------------------------------------------
# Elemanları ardışık sayılar olan karışık bir liste verilir. Listenin en küçük öğesi ile en büyük öğesi arasında bulunan ancak listede gösterilmeyen çift sayıdaki eksik sayıların çıktısını veren bir python kodu yazın.
#
# Giriş
#
# liste = [48, 10, 11, 21, 36, 5, 6, 52, 28, 29, 53, 54, 45, 19, 20, 47, 55, 39, 41, 7, 9, 17, 26, 27 , 42, 22, 37, 51, 46, 18, 44, 30, 34, 13, 15, 35, 33, 16, 50, 24]
#
# Beklenen Çıktı: 8 12 14 32 38 40

# %%
liste = [48, 10, 11, 21, 36, 5, 6, 52, 28, 29, 53, 54, 45, 19, 20, 47, 55, 39, 41, 7, 9, 17, 26, 27 , 42, 22, 37, 51, 46, 18, 44, 30, 34, 13, 15, 35, 33, 16, 50, 24]
liste.sort()

even = []
for i in range(min(liste), max(liste)+1):
  if i not in liste and i % 2 == 0:
    even.append(i)
print(even)
# Out:
# [8, 12, 14, 32, 38, 40]

# %% [markdown]
# 2 ) Try to print a multiplication table with numbers from 1 to 10.
# --------------------------------------------------------------------------
# 1'den 10'a kadar sayılar içeren bir çarpım tablosu yazdırmayı deneyin.
# ---------------------------------------------------------------------------
# For Example,
#
# 1 x 1 = 1
#
# 1 x 2 = 2
#
# 1 x 3 = 3
#
# 1 x 4 = 4
#
# 1 x 5 = 5
#
# 1 x 6 = 6
#
# 1 x 7 = 7
#
# 1 x 8 = 8
#
# 1 x 9 = 9
#
# 1 x 10 = 10
#
# ***********
#
# 2 x 1 = 2
#
# 2 x 2 = 4
#
# 2 x 3 = 6

# %%
for i in range(1, 11):
  for s in range(1, 11):  
    print(f"{i}x{s}={i*s}")
  print('**********')
# Out:
# 1x1=1
# 1x2=2
# 1x3=3
# 1x4=4
# 1x5=5
# 1x6=6
# 1x7=7
# 1x8=8
# 1x9=9
# 1x10=10
# **********
# 2x1=2
# 2x2=4
# 2x3=6
# 2x4=8
# 2x5=10
# 2x6=12
# 2x7=14
# 2x8=16
# 2x9=18
# 2x10=20
# **********
# 3x1=3
# 3x2=6
# 3x3=9
# 3x4=12
# 3x5=15
# 3x6=18
# 3x7=21
# 3x8=24
# 3x9=27
# 3x10=30
# **********
# 4x1=4
# 4x2=8
# 4x3=12
# 4x4=16
# 4x5=20
# 4x6=24
# 4x7=28
# 4x8=32
# 4x9=36
# 4x10=40
# **********
# 5x1=5
# 5x2=10
# 5x3=15
# 5x4=20
# 5x5=25
# 5x6=30
# 5x7=35
# 5x8=40
# 5x9=45
# 5x10=50
# **********
# 6x1=6
# 6x2=12
# 6x3=18
# 6x4=24
# 6x5=30
# 6x6=36
# 6x7=42
# 6x8=48
# 6x9=54
# 6x10=60
# **********
# 7x1=7
# 7x2=14
# 7x3=21
# 7x4=28
# 7x5=35
# 7x6=42
# 7x7=49
# 7x8=56
# 7x9=63
# 7x10=70
# **********
# 8x1=8
# 8x2=16
# 8x3=24
# 8x4=32
# 8x5=40
# 8x6=48
# 8x7=56
# 8x8=64
# 8x9=72
# 8x10=80
# **********
# 9x1=9
# 9x2=18
# 9x3=27
# 9x4=36
# 9x5=45
# 9x6=54
# 9x7=63
# 9x8=72
# 9x9=81
# 9x10=90
# **********
# 10x1=10
# 10x2=20
# 10x3=30
# 10x4=40
# 10x5=50
# 10x6=60
# 10x7=70
# 10x8=80
# 10x9=90
# 10x10=100
# **********

# %% [markdown]
# 3 ) Write a program to check if two string are balanced.
# ## for example; strings s1 and s2 are balanced if all the characters in the s1 are present in s2
# --------------------------------------------------------------------------------------------------
# İki dizenin dengeli olup olmadığını kontrol eden bir program yazın.
# örneğin; s1'deki tüm karakterler s2'de mevcutsa, s1 ve s2 dizeleri dengelenir

# %%
s1 = input('aranacak kelime: ')
s2 = input('aranan kelime: ')

if set(s1)-set(s2) == set():
  print('dengededir.')
else:
  print('dengede değildir.')
# Out:
# aranacak kelime: gh
# aranan kelime: fghj
# dengededir.

# %%
set(s1)-set(s2) == set()
# Out:
# True

# %%
s1 = input('aranacak kelime: ')
s2 = input('aranan kelime: ')
print(s1 not in s2)
# Out:
# aranacak kelime: gh
# aranan kelime: ghj
# False

# %%
s1 = input('aranacak kelime')
s2 = input('aranan kelime')
set(s1)-set(s2)
# Out:
# aranacak kelimejkl
# aranan kelimehjkl
# set()

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# 4)  set() | for loop | floor division | format() | "string"
#
# There is a large of socks that must be paired by color. Given an array of integers representing the color of each sock, determine how many pairs of socks with matching colors there are.
#
# Example :
#
# n = 7
#
# ar = [1, 2, 1, 2, 1, 3, 2]
#
# --------------------------------------------------------------------------
# Renge göre eşleştirilmesi gereken çok sayıda çorap var. Her bir çorabın rengini temsil eden bir tamsayı dizisi verildiğinde, eşleşen renklere sahip kaç çift çorap olduğunu belirleyin.
#
# Örnek :
#
# sayı = 7
#
# ar = [1, 2, 1, 2, 1, 3, 2]

# %%
ar = [1, 2, 1, 2, 1, 3, 2, 1, 3]
renk_listesi = set(ar)
renk = []
çift = 0
for i in renk_listesi:
  if ar.count(i) // 2 :
    çift += 1
    renk.append(i)
print(f"toplam {çift} çift çorap vardır", "Renk kodları ise {}".format(renk))
# Out:
# toplam 3 çift çorap vardır Renk kodları ise [1, 2, 3]

# %% [markdown]
# ----------------------------------------------------------------------------------------------

# %% [markdown]
#  5 ) for loop | sum()
#
# Abigail and Benson are playing Rock, Paper, Scissors.
#
# Each game is represented by an array of length 2, where the first element represents what Abigail played and the second element represents what Benson played.
#
# Given a sequence of games, determine who wins the most number of matches. If they tie, output "Tie".
#
# - R stands for Rock
#
# - P stands for Paper
#
# - S stands for Scissors
# ----------------------------------------
# Abigail ve Benson, Taş, kağıt ve makas oynuyorlar.
#
# Her oyun 2 uzunluğunda bir diziyle temsil edilir; burada ilk öğe Abigail'in oynadığını ve ikinci öğe Benson'ın oynadığını temsil eder.
#
# Bir dizi oyun verildiğinde, en çok maçı kimin kazandığını belirleyin. Bağlanırlarsa, 'Tie' çıktısını alın.
#
# - R, Rock anlamına gelir
#
# - P, Kağıt anlamına gelir
#
# - S, Makas anlamına gelir

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# 6)Create a function that returns the sum of missing numbers from the given list.
#
# Examples
#
# sum_missing_numbers([4, 3, 8, 1, 2]) ➞ 18
#
# - 5 + 6 + 7 = 18
#
# sum_missing_numbers([17, 16, 15, 10, 11, 12]) ➞ 27
#
# - 13 + 14 = 27
#
# sum_missing_numbers([1, 2, 3, 4, 5]) ➞ 0
#
# - No Missing Numbers (i.e. all numbers in [1, 5] are present in the list)
# -----------------------------------------------------------------------
# Verilen listedeki eksik sayıların toplamını döndüren bir işlev oluşturun.
# Örnekler
#
# sum_missing_numbers([4, 3, 8, 1, 2]) ➞ 18
#
# - 5 + 6 + 7 = 18
#
# sum_missing_numbers([17, 16, 15, 10, 11, 12]) ➞ 27
#
# - 13 + 14 = 27
#
# sum_missing_numbers([1, 2, 3, 4, 5]) ➞ 0
#
# - Eksik Numara Yok (yani [1, 5] içindeki tüm numaralar listede mevcut)

# %%
a = [4, 3, 8, 1, 2]
b = sorted(a)
toplam = 0
for i in range(b[0], b[-1]):
  if i not in b:
    toplam += i
print(toplam)
# Out:
# 18

# %%
a = [4, 3, 8, 1, 2]
top = 0

for i in range(min(a), max(a)+1):
   if i not in a:
    top += i
print(top)
# Out:
# 18

# %% [markdown]
# ---------------------------------------------------------------------------------------

# %% [markdown]
# 7)Bir pisagor üçgeni oluşturan 1'den 100'e kadar sayıları ekrana yazdıran bir program yazın. Sınav için.: 3 4 5

# %%
# 3 4 5
# a**2 + b**2 = c**2
for a in range(1, 100):
  for b in range(a, 100):
    for c in range(b, 100):
      if  a**2 + b**2 == c**2:
        print(a, b, c)
# Out:
# 3 4 5
# 5 12 13
# 6 8 10
# 7 24 25
# 8 15 17
# 9 12 15
# 9 40 41
# 10 24 26
# 11 60 61
# 12 16 20
# 12 35 37
# 13 84 85
# 14 48 50
# 15 20 25
# 15 36 39
# 16 30 34
# 16 63 65
# 18 24 30
# 18 80 82
# 20 21 29
# 20 48 52
# 21 28 35
# 21 72 75
# 24 32 40
# 24 45 51
# 24 70 74
# 25 60 65
# 27 36 45
# 28 45 53
# 30 40 50
# 30 72 78
# 32 60 68
# 33 44 55
# 33 56 65
# 35 84 91
# 36 48 60
# 36 77 85
# 39 52 65
# 39 80 89
# 40 42 58
# 40 75 85
# 42 56 70
# 45 60 75
# 48 55 73
# 48 64 80
# 51 68 85
# 54 72 90
# 57 76 95
# 60 63 87
# 65 72 97

# %% [markdown]
# --------------------------------------------------------------------------------------

# %% [markdown]
# 8) input() | len() | set()
#
# Write a Python function that takes a sequence of numbers and determines whether all the numbers are different from each other.
#
# Bir sayı dizisi alan ve tüm sayıların birbirinden farklı olup olmadığını belirleyen bir Python fonksiyonu yazın.

# %%
a = [1, 2, 3, 4, 4]


print(len(a) == len(set(a)))
# Out:
# False

# %%
set(a)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# -----------------------------------------------------------------------------------------

# %% [markdown]
# 9)for loop | nested for loop | range() |?str() | int()
#
#  - How many of the 3-digit numbers are equal to the sum of the cubes of their digits?
#
#  - 3 basamaklı sayıların kaç tanesi rakamlarının küplerinin toplamına eşittir?

# %%
# abc = a**3+b**3+c**3
küp_yoplamı = 0
sayaç = 0
for i in range(100, 1000):
  for f in str(i):
    küp_yoplamı+= int(f)**3
  if küp_yoplamı == i:
    print(i)
    sayaç += 1
  küp_yoplamı = 0  
print("3 basamaklı sayıların {} tanesinin küplerinin toplamı kendisine eşittir.".format(sayaç))
# Out:
# 153
# 370
# 371
# 407
# 3 basamaklı sayıların 4 tanesinin küplerinin toplamı kendisine eşittir.

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
for i in range(10):
  if i == 3: # skips if i is 3
    continue
  print(i)
# Out:
# 0
# 1
# 2
# 4
# 5
# 6
# 7
# 8
# 9

# %%
int('100'[0])**2
# Out:
# 1

# %% [markdown]
# 10 )comprehension | nested for loop | for loop | join()
#
# Write a program that square every digit of a number and concatenate them.
# For example, if we run 9119 through the function, 811181 will come out, because 9 ** 2 = 81 and 1 ** 2 = 1.
#
# Bir sayının her basamağını karesini alan ve bunları birleştiren bir program yazın. Örneğin 9119'u fonksiyon üzerinden çalıştırırsak sonuç 811181 çıkacaktır, çünkü 9 ** 2 = 81 ve 1 ** 2 = 1'dir.

# %%
a = 256

list = ""

for i in str(a):
  b = str(int(i)**2)
  list += b
print(list)
# Out:
# 42536

# %%
a = 4
b = 3
c = 4

print((a+b+c)/10)
# Out:
# 1.1

# %%
sum = 0
for i in range(1,11):
  n = float(input(f"Enter {i}. students grade  :"))
  sum += n
print(f"Avarage grades of students is  = {sum/10}")
# Out:
# Enter 1. students grade  :2
# Enter 2. students grade  :3
# Enter 3. students grade  :5
# Enter 4. students grade  :5
# Enter 5. students grade  :4
# Enter 6. students grade  :6
# Enter 7. students grade  :5
# Enter 8. students grade  :6
# Enter 9. students grade  :5
# Enter 10. students grade  :2
# Avarage grades of students is  = 4.3

# %%
not_toplamı = 0
for i in range(1, 11):
  notlar = int(input(f"{i}. öğrencinin notunu giriniz: "))
  not_toplamı += notlar

print(f"öğrencilerin not ortalaması = {not_toplamı/10}" )
# Out:
# 1. öğrencinin notunu giriniz: 2
# 2. öğrencinin notunu giriniz: 3
# 3. öğrencinin notunu giriniz: 2
# 4. öğrencinin notunu giriniz: 3
# 5. öğrencinin notunu giriniz: 2
# 6. öğrencinin notunu giriniz: 3
# 7. öğrencinin notunu giriniz: 2
# 8. öğrencinin notunu giriniz: 3
# 9. öğrencinin notunu giriniz: 2
# 10. öğrencinin notunu giriniz: 3
# öğrencilerin not ortalaması = 2.5

# %%
# 40 saat altı saatlik ücret tarifesi = 100 $
# 40 saat üstü saatlik ücret tarifesi = 150 $

çalışma_saati = int(input('Haftada kaç saat çalışıyorsunuz: '))
ücret = 0
if çalışma_saati < 40 :
  m = çalışma_saati * 100
  ücret += m
elif çalışma_saati > 40 :
  n = (çalışma_saati-40) * 150
  ücret += n
print(f"Haftalık Ücretiniz: {ücret} $ dır.")
# Out:
# Haftada kaç saat çalışıyorsunuz: 30
# Haftalık Ücretiniz: 3000 $ dır.

# %%
t = int(input("Enter the total number of hours this week."))
if t <= 40:
  print(f"Your weekly income {t*20} $") 
elif t >= 40:
  print (f"Your weekly income {(40*20)+(t-40)*30} $")
# Out:
# Enter the total number of hours this week.50
# Your weekly income 1100 $
