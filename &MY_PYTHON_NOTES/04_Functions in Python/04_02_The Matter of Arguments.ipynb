# %%
# positional argüman --> sırası önemli ona göre atama yapılmalıdır.

a = "i"     # Positional argumant örneği.
b = "love" 
c = "you"
def texter(text1, text2, text3):
  print(text2, text3, text1)

# %%
texter(c, a, b)
# Out:
# i love you

# %%
def who(first, last) :  # 'first' and 'last' are the parameters(or variables)
    print('Your first name is :', first)
    print('Your last name is :', last)

who('Guido', 'van Rossum')  # 'Guido' and 'van Rossum' are the arguments
print()
who('Marry', 'Bold')  # 'Marry' and 'Bold' are also the argument
# Out:
# Your first name is : Guido
# Your last name is : van Rossum
#
# Your first name is : Marry
# Your last name is : Bold

# %%
def pos_args(a, b):
    print(a, 'is the first argument')
    print(b, 'is the second argument')

pos_args(3,4)
print()
pos_args(4,3)
# Out:
# 3 is the first argument
# 4 is the second argument
#
# 4 is the first argument
# 3 is the second argument

# %%
def bir_fonk(x = 'ali', y = '22'):  #  keyword arguman.
  print(x, y, 'yaşındadır.')

# %%
bir_fonk()   #  keyword argumanda argüman girilmezse dahi default değerler döndürülür.
# Out:
# ali 22 yaşındadır.

# %%
bir_fonk(y = 33, x = 'murat')  # keyword argumanda arguman yerleri değişebiliyor.
# Out:
# murat 33 yaşındadır.

# %%
bir_fonk() # tekrar argüman girilmezse dahi default değerler döndürülür. bir önceki kod da parametrelere farklı değerler atanması etkilemedi.
# Out:
# ali 22 yaşındadır.

# %%
bir_fonk('melih', 40) # Keyword u yazmadık yine çıktı aldı.
# Out:
# melih 40 yaşındadır.

# %%
bir_fonk('ömer') # tek değer atadık ilk parametreye kendini atadı.(positinal arguman şeklinde atama olursa argumanlara sırayla atanır.)
# Out:
# ömer 22 yaşındadır.

# %%
bir_fonk(55)  #  tek değer atadık ilk parametreye kendini atadı.
# Out:
# 55 22 yaşındadır.

# %%
bir_fonk(55, 'ömer')  #  tek değer atadık ilk parametreye kendini atadı.
# Out:
# 55 ömer yaşındadır.

# %%
def parrot(voltage, state='a stiff', action='voom', type='Norwegian Blue'):
    print("-- This parrot wouldn't", action, end=' ')
    print("if you put", voltage, "volts through it.")
    print("-- Lovely plumage, the", type)
    print("-- It's", state, "!")

# %%
parrot()  # çıktı vermez çünkü fonksiyonda positional Argüman (voltage) var.
# tanımlamada positional argümanların default değerleri yoktur. 
# bu yüzden fonk.da positional argüman varsa mutlaka ona değer atanmalı.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\user\OneDrive\IT\PYTHON\&PYTHON\&MY_PYTHON_NOTES\04_Functions in Python\04_02_The Matter of Arguments.ipynb Hücre 15 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/IT/PYTHON/%26PYTHON/%26MY_PYTHON_NOTES/04_Functions%20in%20Python/04_02_The%20Matter%20of%20Arguments.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> parrot()
#
# TypeError: parrot() missing 1 required positional argument: 'voltage'

# %%
parrot(1000)                                          # 1 positional argument
parrot(voltage=1000)                                  # 1 keyword argument
parrot(voltage=1000000, action='VOOOOOM')             # 2 keyword arguments
parrot(action='VOOOOOM', voltage=1000000)             # 2 keyword arguments 
parrot('a million', 'bereft of life', 'jump')         # 3 positional arguments
parrot('a thousand', state='pushing up the daisies')  # 1 positional, 1 keyword
# Out:
# -- This parrot wouldn't voom if you put 1000 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !
# -- This parrot wouldn't voom if you put 1000 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !
# -- This parrot wouldn't VOOOOOM if you put 1000000 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !
# -- This parrot wouldn't VOOOOOM if you put 1000000 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !
# -- This parrot wouldn't jump if you put a million volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's bereft of life !
# -- This parrot wouldn't voom if you put a thousand volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's pushing up the daisies !

# %%
parrot(voltage = 1000000, action = "VOOOOOOM")  # çağırırken tüm argümanları keyword olarak yolladık.
# Out:
# -- This parrot wouldn't VOOOOOOM if you put 1000000 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !

# %%
parrot(action = "VOOOOOOM", voltage = 1000000)  # keyword argümanların sırasını değiştirdik. aynı çıktıyı verdi.
# Out:
# -- This parrot wouldn't VOOOOOOM if you put 1000000 volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's a stiff !

# %%
parrot("A MILLION", "BEREFT OF LIFE", "JUMP" )  
# tüm argümanları positional olarak yolladık. foksiyondaki yerlerine sırayla gitti.
# Out:
# -- This parrot wouldn't JUMP if you put A MILLION volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's BEREFT OF LIFE !

# %%
parrot("A THOUSAND", state = "PUSHING UP THE DAISIES" )  # pos. ve keyword argümanları beraber yolladık.
# Out:
# -- This parrot wouldn't voom if you put A THOUSAND volts through it.
# -- Lovely plumage, the Norwegian Blue
# -- It's PUSHING UP THE DAISIES !

# %%
parrot(voltage = 5, "dead") # positional argümanlar mutlaka keyword argümanlardan önce yazılmalı!

# %%
parrot(state = "BALL", "a billion")

# %%
def argu(a, b = "dünya", c, d = "satürn") : # fonk tanımlarkende pos A. daima en önde olmalı.
    print(a, b, c, d, sep="\n")

# %%
def argu(a, c, b = "dünya", d = "satürn") :
    print(a, b, c, d, sep="\n")

# %%
argu()  # Çalışmaz çünkü 2 konumsal Arguman (a, c) var . 2 arguman atamazsak çalışmaz.

# %%
argu("uranus", "jupyter") # argumanlar konumsallara atandı.
# Out:
# uranus
# dünya
# jupyter
# satürn

# %%
argu(a = "uranüs", c = "jupyter") # konumsalları keyword yaptık.
# Out:
# uranüs
# dünya
# jupyter
# satürn

# %%
argu("plüto", c = "venüs", "mars") # çalışmaz çünkü keyw den sonra pos. A gelmiş.

# %%
argu(d = "guneş", a = "dünya", c = "plüto", b = "venüs")  # yer değiştirdik yinede oldu.
# Out:
# dünya
# venüs
# plüto
# guneş

# %%
def argu(a, c, b = "dünya", d = "satürn") :
    print(a, b, c, d, sep="\n")

# %%
argu("guneş", "dünya", "plüto", "venüs")
# Out:
# guneş
# plüto
# dünya
# venüs

# %% [markdown]
# Arbitrary Number of
# Arguments Önemli: **kwargs, dicts formatına uygun olarak çalışır

# %%
def name(*parametre):   # Syntaxı
  name(multiple args)

def name(**parameter):
  name(multiple kwars)

# %%
def fruiterer(*fruit) :
    for i in fruit :
        print(i, end = " ")

fruiterer("orange", "banana", "melon", "ananas")
# Out:
# orange banana melon ananas

# %%
def fruiterer(*fruit) :
    print(type(fruit))
fruiterer("orange", "banana", "melon", "ananas")
# Out:
# <class 'tuple'>

# %%
def slicer(*num) :
    even = []
    odd = []
    
    for i in num : 
        if i % 2 == 0 :
            even.append(i)
        else :
            odd.append(i)
    print("even list :", even)
    print("odd list :", odd)

# %%
 slicer(1,2,3,4,5,6,7,8,9)
# Out:
# even list : [2, 4, 6, 8]
# odd list : [1, 3, 5, 7, 9]

# %%
# Farklı yöntemle;
def slicer(* numbers):
  even = numbers[1::2] # Tuple meyilli.
  odd = [numbers[0::2]]
  print("even list :", even)
  print("odd list :", odd)
slicer(1,2,3,4,5,6,7,8,9)
# Out:
# even list : (2, 4, 6, 8)
# odd list : [(1, 3, 5, 7, 9)]

# %%
deha = ('bill', 'rossum', 'guido van', 'gates')
def dehalar(a1, a2, a3, a4):
  print(f"bence, {a1} {a4} and {a3} {a2} dehadır.")

dehalar(*deha)
# Out:
# bence, bill gates and guido van rossum dehadır.

# %%
def concatenate(*arg):
  return '-'.join(arg)

print(concatenate("I", "love", "Python", "!"))
# Out:
# I-love-Python-!

# %%
def yaşlar(** ailem):
  isimler = []
  yaşları = []

  for key, value in  ailem.items() :
    isimler.append(key)
    yaşları.append(value)

  print(isimler, yaşları, sep='\n')

# %%
yaşlar(sem = 12, küb = 7, nev = 1, jdd=2)
organizer(sem = 12, küb = 7, nev = 1, jdd=2)
# Out:
# ['sem', 'küb', 'nev', 'jdd']
# [12, 7, 1, 2]
# ['sem', 'küb', 'nev', 'jdd']
# [12, 7, 1, 2]

# %%
def yaşlar(**ailem):
  isimler = [i for i in ailem.keys()]
  yaşları = [i for i in ailem.values()]

  print(isimler, yaşları, sep='\n')

yaşlar(semr = 12, kübr = 7, nevr = 1)
# Out:
# ['semr', 'kübr', 'nevr']
# [12, 7, 1]

# %%
def yaşlar(**ailem):
  a = 0
  isimler = [i for i in ailem.keys()]
  yaşları = [i for i in ailem.values()]
  yaşları1 = [a +=i for i in ailem.values()]  # Dictionary mantığına göre çalışır. 3. eleman olmaz.

  # avg = [a = i + a for i in ailem.values()]
  print(isimler, yaşları, yaşları1, sep='\n')

yaşlar(semr = 12, kübr = 7, nevr = 1)
# Out:
#   File "<ipython-input-39-2a6fa00fbdb8>", line 5
#     yaşları1 = [a +=i for i in ailem.values()]
#                    ^
# SyntaxError: invalid syntax

# %%
def örnek(x='ali', y='veli'):
  print(x, 'x kuşağındadır.')
  print(y, 'y kuşağındadır.')

soru = {'y':'Faruk', 'x': 'mine'}
soru1 = {'z':'Faruk', 'm': 'mine'}
örnek(**soru) 
#örnek(**soru1) #çalışmaz çünkü keyler değişti.
# Out:
# mine x kuşağındadır.
# Faruk y kuşağındadır.

# %% [markdown]
# filter()

# %%
def cümledeki_ünlüler(metin):
  ünlüler = "a e u i u o ü ö ı".split()
  if metin.lower() in ünlüler :
    return True
  else:
    return False

# %%
cümle = "ben python'u sevmeye başladım."
filter(cümledeki_ünlüler, cümle)

# %%
filtrelenmiş_ünlüler = filter(cümledeki_ünlüler, cümle)

# %%
list(filtrelenmiş_ünlüler)
# Out:
# ['e', 'o', 'u', 'e', 'e', 'e', 'a', 'a', 'ı']

# %%
print(* filtrelenmiş_ünlüler)
# Out:
# e o u e e e a a ı

# %%
cümle = "ben python'u sevmeye başladım."
print(filter(None, cümle))

# %%
cümle = "ben python'u sevmeye başladım."
print(*filter(None, cümle))
# Out:
# b e n   p y t h o n ' u   s e v m e y e   b a ş l a d ı m .

# %%
def fonks(a): # pas body kısmını daha sonra yazacağım hata verme demek. 
  pass

fonks(a=0)

# %%
  def city(capital, continent='Europe'):
    print(capital, 'in', continent)

city('Athens')  # we don't have to pass any arguments into 'continent'
city('Ulaanbaatar', continent='Asia')  # we can change the default value by kwargs
city('Cape Town', 'Africa')  # we can change the default value by positional ar
# Out:
# Athens in Europe
# Ulaanbaatar in Asia
# Cape Town in Africa

# %%
def fruiterer(fruit1, fruit2) :
    print('I want to get', fruit1, 'and', fruit2)
        
fruiterer('orange', 'banana')  # Kullanıcı iki çeşitten fazla meyve almak isterse ne olur?
# Out:
# I want to get orange and banana

# %%
def fruiterer(*fruit) :
    print(fruit)
    print('I want to get :')
    for i in fruit :
      print('-', i)

        
fruiterer('orange', 'banana', 'melon', 'ananas')
# Out:
# ('orange', 'banana', 'melon', 'ananas')
# I want to get :
# - orange
# - banana
# - melon
# - ananas

# %%
def animals(**kwargs):
    for key, value in kwargs.items():
        print(value, "are", key)
 
animals(Carnivores="Lions", Omnivores="Bears", Herbivores="Deers", Nomnivores="Human")
# Out:
# Lions are Carnivores
# Bears are Omnivores
# Deers are Herbivores
# Human are Nomnivores

# %%
def brothers(bro1, bro2, bro3):
    print('Here are the names of brothers :')
    print(bro1, bro2, bro3, sep='\n')

family = ['tom', 'sue', 'tim']
brothers(*family)
# Out:
# Here are the names of brothers :
# tom
# sue
# tim

# %%
def gene(x='Solomon', y='David'):  # defined by kwargs (default values assigned to x and y)
    print(x, "belongs to Generation X")
    print(y, "belongs to Generation Y")

# %%
dict_gene = {'y' : "Marry", 'x' : "Fred"}
gene(**dict_gene)
# Out:
# Fred belongs to Generation X
# Marry belongs to Generation Y

# %%
dict_gene = {'y' : "Marry", 'x' : "Fred"}
gene(dict_gene)
# Out:
# {'y': 'Marry', 'x': 'Fred'} belongs to Generation X
# David belongs to Generation Y

# %%
def standard_arg(arg):
    print(arg)

standard_arg(2)
standard_arg(arg=2)
# Out:
# 2
# 2

# %%
def pos_only_arg(arg, /):
    print(arg)

# %%
def kwd_only_arg(*, arg):
    print(arg)

kwd_only_arg(arg=3) 
#kwd_only_arg(3)  # hata

# %%
def combined_example(pos_only_arg, standard, kwd_only_arg):
    print(pos_only_arg, standard, kwkwd_only_argd_only)

# %%
def foo(name, **kwds):
    return 'name' in kwds

# %%
foo(2, **{'name': 2})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-8a59e937df6d> in <module>()
# ----> 1 foo(2, **{'name': 2})
#
# TypeError: foo() got multiple values for argument 'name'

# %%
def foo(name, /, **kwds):
    return 'name' in kwds

foo(1, **{'name': 2})
# Out:
#   File "<ipython-input-94-21b59f6904e0>", line 1
#     def foo(name, /, **kwds):
#                   ^
# SyntaxError: invalid syntax
