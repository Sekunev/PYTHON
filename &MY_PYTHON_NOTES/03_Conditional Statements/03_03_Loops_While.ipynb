# %%
# WHİLE DÖNGÜLERİ
For döngülerinden biraz farklıdır, for döngüsü ile yapılabilen her şey while döngüsü ile de yapılabilir.
while döngüleri bir bloktan oluşur; belli bir koşul sağlandığı sürece yani sonuç True olduğu sürece bloğundaki işlemleri gerçekleştirmeye devam eder.
While döngülerinin sona ermesi için koşul durumunun bir süre sonra False olması gereklidir. Yapısı şu şekildedir;
                    while (koşul):
                      İşlem1
                      işlem2
                      işlem3
                       //
                      //        # işlem 1 den başlayıp teker teker gerçekleştirir; Döngüde yapacak bir şey kalmayınca döngü tamamen başa dönüyor. 
                                # Sonra tekrar koşulu kontrol edip işlemleri yapmaya başlıyor. 
                                # Koşul ne zaman false olacak; işlemden herhangi biri koşulu False yapacak şekilde yazılmıştır, aksi halde sonsuz döngüye girer.
  while döngülerini daha iyi anlamak için örneklere bakalım.

# %%
FOR DÖNGÜSÜ İLE WHİLE DÖNGÜSÜ ARASINDAKİ EN ÖNEMLİ FARK; FOR DÖNGÜSÜNDE SONSUZ DÖNGÜ RİSKİMİZ YOK.
AMA WHİLE DÖNGÜSÜNDE DEĞİŞKENİ BİR ARTIRMA İŞİNİ YAPMAZSAK SONSUZ DÖNGÜYE GİRERİZ.

# %%
# Döngüde i değerlerini ekrana yazdırma.

i = 0
while (i < 5):    # i 10 dan küçük olduğu sürece işleme devam et. 
    # (KOŞUL) Döngü bitince buraya tekar dönecek 10<10 sonucu False olunca döngü bitiyor.
  print("i'nin değeri", i)
  i += 1 #  Koşulun bir süre sonra False olması için gerekli, bunu yazmazsak sonsuz döngü olur.  - UNUTMAYALIM.

  # İ koşulu 10 dan küçük olan tüm değerleri gezdikten sonra tekrar başa dönüyor;
# bakıyor 10<10 mu diye durum False olduğu içinde döngüyü bitiriyor.
# Out:
# i'nin değeri 0
# i'nin değeri 1
# i'nin değeri 2
# i'nin değeri 3
# i'nin değeri 4

# %%
while 0 : # while condition'a bakar. condition daki koşul True olduğu sürece döngü devam eder.
  print'(ali')  # burada condition False olduğundan print'e geçmez.

# %%
while 0 :
  print('ali')
print('veli')
# Out:
# veli

# %%
condition = 3
while condition:  # sonsuz döngü. bir yerde durmak lazım.
  print(condition)

# %%
condition = 3
while condition:  
  print(condition)
  condition -=1  # her turda değerini 1 kere düşürdük. 0 False geldi ve durdu.
# Out:
# 3
# 2
# 1

# %%
condition = 5
while True:  # kosul True olduğu için sonsuza kadar devam eder.
  condition -= 1
  print(condition)  # bir durak koymalıyız.
  if condition == 0:
    break
# Out:
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# isdigit() isnumeric () metodu

# %%
yaş_1 = 'üç'    # str olacak, numerik olacak.
kilo_1 = '12.9' # içerisinde . , - benzeri olursa False.
kilo_2 = '-5'
yaş_2 = '3'     # sadece rakam olacak.     
print(yaş_1.isdigit())
print(kilo_1.isdigit())
print(kilo_2.isdigit())
print(yaş_2.isdigit())
print(kilo_2.isnumeric())
# Out:
# False
# False
# False
# True
# False

# %%
age = input("Enter your age :")

while not age.isdigit() :
    print("You entered incorrectly!")
    age = input("Enter your age :")
print("Great! you entered valid input and your age is : ", age)
# Out:
# Enter your age :lk55
# You entered incorrectly!
# Enter your age :55
# Great! you entered valid input and your age is :  55

# %% [markdown]
# DÖNGÜLERDE KULLANILAN BREAK VE CONTİNUE İFADELERİ; BREAK İFADESİ Break ifadesi döngülerde programcılar tarafından en çok kullanılan ifadedir. Anlamı şu şekildedir; Döngü herhangi bir yerde ve herhangi bir zamanda break ifadesiyle karşılaştığı zaman çalışmasını bir anda durdurur. Böylelikle döngü hiçbir koşula bağlı kalmadan sonlanmış olur.
#
# break ifadesi SADECE VE SADECE içinde bulunduğu döngüyü sonlandırır. Eğer iç içe döngüler bulunuyorsa ve en içteki döngüde break kullanılmışsa sadece içteki döngü sona erer, örnek verelim;

# %%
total = 0
while True:
  num = input("Sayı:")
  if num == 'q':
    print(total)
    break
print(total)
# Out:
# Sayı:5
# Sayı:6
# Sayı:q
# 0
# 0

# %% [markdown]
# # CONTİNUE İFADESİ
# continue ifadesi break e göre daha az kullanılır.
#     Döngü herhangi bir yerde ve herhangi bir zamanda continue ifadesiyle karşılaştığı zaman geri kalan işlemlerini
#     yapmadan direk olarak bloğunun başına (yani koşulu kontrol etme yerine)  döner.
# continue ifadesi için örneklere bakalım.

# %%
liste = [1, 2, 3, 4, 5, 6, 7]
for i in liste: # burada continue kullanalım.
  if (i ==3 or i == 5):      # i = 1 old. i = 2 old. bu koşul sağlanmıyor ve ekrana i değerleri basılıyor. Fakat i == 3 old.koşul sağlandığı için ekarana i=3 basılmıyor.
                            # ve döngü kalanı yapma en başa tekrar git diyor. artık i = 4 old. için onu basıyor, fakat i = 5 old. koşul sağlandığı için basılmıyor
                            # ve yine en başa geri dönüyor artık  i = 6 olduğundan i=6 yı ve i = 7 ekrana yazdırıyor.
    continue                
  print('i:', i)
# Out:
# i: 1
# i: 2
# i: 4
# i: 6
# i: 7

# %%
# kodun sorunsuz hali
i = 0 
while (i < 10):
  if (i == 2):     # değer bir artıp da 3 olduktan sonra artık buraya girmez alt kısımdan devam eder, döngü.
    i += 1  # i nin sürekli 2 kalmaması için bizim burada continue dan önce bir işlem yapmamız lazım bu işlem de artırma işlemidir.
    continue
  print(i)             # i = 2 olduğunda buradaki print devreye girmez.
  i +=1

# %%
i = 1  # continunun alternatifi
while (i < 10):
  if (not(i == 2) and not(i == 5)):
    print(i)
  i += 1
# Out:
# 1
# 3
# 4
# 6
# 7
# 8
# 9

# %%
number = 0  # Değişken bu döngüde bir sayaç görevi görür.
while number < 10:  # değişken, her yinelemeden sonra değerini değiştirir. 
    print(number)  # Sayacın değeri 10'ya ulaştığında program kontrolü bir sonraki işleme geçer ve aşağıdaki metni yazdırır.
    number += 4
print('now, number is bigger or equal to 10')
# Out:
# 0
# 4
# 8
# now, number is bigger or equal to 10

# %%
my_list=["a", "b", "c", "d", "e"]

a = 0

while a < len(my_list):
    print('square of {} is : {}'.format(a, a**2))
    a+=1
# Out:
# square of 0 is : 0
# square of 1 is : 1
# square of 2 is : 4
# square of 3 is : 9
# square of 4 is : 16

# %%
cevap = 46
question = 'aklımdaki sayı kaç? '
print('Hadi Tahmin oyunu oynayalım.')
while True:
  tahmin = int(input(question))
  if tahmin<cevap:
    print('yukarı çık')
  elif tahmin>cevap:
    print('aşağı in')
  else:
    print('doğru tahmin')
    break  # döngünün sona ermesi için break anahtar kelimesi kullanıldı.
# Out:
# Hadi Tahmin oyunu oynayalım.
# aklımdaki sayı kaç? 20
# yukarı çık
# aklımdaki sayı kaç? 65
# aşağı in
# aklımdaki sayı kaç? 46
# doğru tahmin

# %%
tr_harfler = "şçöğüİı"
a = 0

while a < len(tr_harfler):
    print(tr_harfler[a], sep="\n")
    a += 1
# Out:
# ş
# ç
# ö
# ğ
# ü
# İ
# ı

# %% [markdown]
# Yazılan bir cümlenin en uzun kelimesinin karekter sayısını bulan kod yazalım.**kalın metin**

# %%
sentence = 'The best school is Clarusway btcamp '
kelime_listesi = sentence.split()
uzunluk = 0
a = 0
while len(kelime_listesi) > a :
  if len(kelime_listesi[a]) > uzunluk :
    uzunluk = len((kelime_listesi[a]))
  a +=1
for i in kelime_listesi:
  if len(i) == uzunluk:
    uzun_kelime = i
print(f"Cümledeki en uzun kelime:{uzun_kelime} olup, {uzunluk} karakterlidir.")
# Out:
# Cümledeki en uzun kelime:Clarusway olup, 9 karakterlidir.

# %%
'ali'<'veli'  #ascıı code a göre kıyas olduğu için bool değer verir.
# Out:
# True

# %%
condition = 3
while condition:  # break döngüyü bitird.
  print(condition)
  break
print('hello')    # döngü dışı devam ediyor.
# Out:
# 3
# hello

# %%
condition = 3
while condition:  # break döngüyü bitird.
  continue
  print('hello')    # döngü dışı devam ediyor.

# %%
isim = 'asuman'
while True: # while True ne demek; eğer hiçbir yerde break ifadesi kullanılmazsa sonsuz döngüye girilir. Bunu nasıl sonlandırırız?
  isim = input("İsminiz(çıkmak için q tuşuna basın.):")
  if (isim == 'q'):  # break ile tabi ki
    print('Çıkış yapılıyor...')
    break
  print("isimiz:", isim)
print('blok 1 e yazacaklarımızda break komutundan sonra print eder')
