# %% [markdown]
# Syntax Erros ile Exception Errors Farkı;
# syntax hatası varsa ---> compiling aşamasıda byte code aşamasına geçemez
# exception hatası varsa ---> interpretation (yani exception olan satıra kadar çalışır hata olan satırda durur)
# exception lar prg çalışmasına engel değil, hatalı olan yere kadar gelir hatalı olan bir exception üretir.
# mesela bir str ile int toplamaya çalışmak; TypeError exception ı yükselir.
# bu hataya kadar üst satırlar hatasız ise çalışır bu satırda hata yükselir(exception yükselir) çalışmaz.
# hata satırından sonra doğru olan satırlarda çalışmaz.
# EOF; can only concatenate str (not "int") to str (İNT İLE STR toplanamaz)
# COMMON EXCEPTİONS; 3 tanedir.
# * Value Error;tipi uyuyor ama içerik uymuyor.
# * Name Error; tanımlanmamış tüm değişken, fonk etc. bu hatayı verir. Python da tanımlanmamış bir şey varsa bu hatayı verir.
# EOF yı okumayı ve sorunu çözmemiz lazım.
# * Type Error

# %% [markdown]
# sytax error 'da ---> kod hiç çalışmaz,
# exception error'da ---> program çalışır ama hata verir.

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
math.sqrt(-25)  # Buraya karekök ü alınamayacak bitr değer yazarsak hata alırız.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\user\OneDrive\IT\PYTHON\&PYTHON\&MY_PYTHON_NOTES\06_Program Flow, Error _ Exception Handling\00_Errors_Exception_Handling.ipynb Hücre 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/IT/PYTHON/%26PYTHON/%26MY_PYTHON_NOTES/06_Program%20Flow%2C%20Error%20_%20Exception%20Handling/00_Errors_Exception_Handling.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> math.sqrt(-25)
#
# NameError: name 'math' is not defined

# %%
math.log10(10000)
# Out:
# 4.0

# %%
math.log2(16)
# Out:
# 4.0

# %%
math.log(1000)
# Out:
# 6.907755278982137

# %%
math.log(-1000)

# %%
print("hello world")
print("hello world")
print("hello world")
print("hello world")
print("hello world")  # 2/0 hatalı bir giriş o yüzden Exception error 
2/0                   # belirtilen satıra kadar kod çalışır. sonrası çalışmaz.
print("hello world")
print("hello world")
print("hello world")
print("hello world")
print("hello world")
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# c:\Users\user\OneDrive\IT\PYTHON\&PYTHON\&MY_PYTHON_NOTES\06_Program Flow, Error _ Exception Handling\00_Errors_Exception_Handling.ipynb Hücre 8 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/IT/PYTHON/%26PYTHON/%26MY_PYTHON_NOTES/06_Program%20Flow%2C%20Error%20_%20Exception%20Handling/00_Errors_Exception_Handling.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> print("hello world")
#       <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/IT/PYTHON/%26PYTHON/%26MY_PYTHON_NOTES/06_Program%20Flow%2C%20Error%20_%20Exception%20Handling/00_Errors_Exception_Handling.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> print("hello world")  # 2/0 hatalı bir giriş o yüzden Exception error
# ...

# %%
print("hello")    # 2. satırda ise syntax hatası vardır ve bu kod hiç çalışmaz.
print(hello
# Out:
#   Input In [13]
#     print(hello
#                ^
# SyntaxError: incomplete input

# %%
print("hello")  # Yine Exception hatası.
print(hello)
# Out:
# hello
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\user\OneDrive\IT\PYTHON\&PYTHON\&MY_PYTHON_NOTES\06_Program Flow, Error _ Exception Handling\00_Errors_Exception_Handling.ipynb Hücre 10 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/IT/PYTHON/%26PYTHON/%26MY_PYTHON_NOTES/06_Program%20Flow%2C%20Error%20_%20Exception%20Handling/00_Errors_Exception_Handling.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> print("hello")  # Yine Exception hatası.
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/IT/PYTHON/%26PYTHON/%26MY_PYTHON_NOTES/06_Program%20Flow%2C%20Error%20_%20Exception%20Handling/00_Errors_Exception_Handling.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> print(hello)
#
# NameError: name 'hello' is not defined

# %%
while True:
    no_one = int(input("The first number please : "))
    no_two = int(input("The second number please : "))
    division = no_one / no_two
    print("The result of the division is : ", division)
    break
# Out:
# The first number please : 2
# The second number please : 5
# The result of the division is :  0.4

# %% [markdown]
# 1. try bloğu altındaki tüm except blokları içindir
# 2. bir try bloğu için birden fazla exception kullanılabilir
# 3. try bloğunda ki aynı hata için ikinci bir exception çalışmaz, bir tanesi çalışır.

# %% [markdown]
# The basic structure of TRY-EXCEPT statement looks like:
#
# try:
#     {code blocak to be normally executed
#
# except:
#     {code block to be exceptionally executed
#
# * try:
#     girinti
# yazarak aslında biz şunu yapıyoruz:
# kodumuzda muhtemel hata verebilecek yani excepiton yükseltebilecek olan ihtimal dahilinde gördüğümüz kodu try ın içine yazıyoruz.
# Kod burada çalışırsa sorun yok devam eder ama
# orada herhangi bir exception yükselirse buradaki kodu durduruyor ve EXCEPT e geçiyor ve except e yazılan kodları çalıştırıyor.
# kısaca try bloğu şu işe yarıyor:
# bizim exception yükselme ihtimali old. düşündüğümüz yani hata verebileceğini düşündüğümüz kod satırlarını try içine yazıyoruz.eğer bir sorun yoksa kod çalışıyor ve atlıyor (yani except i geçiyor) yani try çalışıyor bitiyor istediğimiz kod çalışıyor, excepti atlıyor ve kod satırından devam ediyor. yani kod try except bloğunun dışından devam ediyor.
# Fakat try bloğu içinde zerodivisionerror(aşağıdaki örneğe bak) gibi böyle bir exception yükselirse o zaman o exception ın yükseldiği satırda duruyor hata vermiyor prg çalışmaya devam ediyor ama exception ın yükseldiği satırın altındaki satırı çalıştırmıyor ve hatanın olduğu yerde kesip except e atlıyor. ve except teki kodu çalıştırıyor.
#
# try ile if arasındaki fark:
# if de bir condition var ama try da yok.
# bir boolean yok.
# sadece exception yükselirse except i çalıştırıyor
# yükselmezse try ı çalıştırıyor.

# %%
while True :
    no_one = int(input("the first number please :"))
    no_two = int(input("the second number please :"))
    
    try :
        division = no_one / no_two    # Bady de hata yoksa Try nloğunu çalıştır.
        print("the result of the division is : ", division)
        break
        
    except : # Bodyde hata varsa ben buradayım. gel beni çalıştır. demiş olduk.
        print("something went wrong...Try again.")
        # break
# Out:
# the first number please :5
# the second number please :0
# something went wrong...Try again.
# the first number please :5
# the second number please :1
# the result of the division is :  5.0

# %%
try : 
    x = 2/1
    print("bende sıkıntı yokmuş demek ki bak çalıştım.")

except :
    print("bir şeyler ters gitti.")
# Out:
# bende sıkıntı yokmuş demek ki bak çalıştım.

# %%
try : 
    print("Ben birinci kod satırıyım.") # Exception hatası olduğu için hatalı koda kadar çalışır.
    x = 2/0
    print("Bende sıkıntı yokmuş demek ki bak çalıştım.")

except :
    print("Bir şeyler ters gitti.")
# Out:
# ben birinci kod satırıyım.
# bir şeyler ters gitti.

# %%
try:
    print(12 / 0)
except ZeroDivisionError as ex:
    print(ex)
# Out:
# division by zero

# %%
try : 
    print("a") # Hata yok o yüzden Exception hiç çalışmaz.
    x = 2/2
    print("b")
    print(x)

except :
    print("c")
# Out:
# a
# b
# 1.0

# %%
num_1 = 250
num_2 = [2,3,5,1,6,0,2,6,7]

res_list= []

for i in num_2:
    try:
        res_list.append(num_1/i)
    except ZeroDivisionError as zero:
        print(zero)
# Out:
# division by zero

# %%
try : 
    print("a")
    x = 2/2
    print("b")
    print(x)

except :    # try-Exeption blogu çalışır. sonra sıra bu blogun dışındaki satıra gelir.
    print("c")
    
print("ben try except bloğunun altındaki satırım.")
# Out:
# a
# b
# 1.0
# ben try except bloğunun altındaki satırım.

# %%
while True :
    no_one = int(input("the first number please :"))
    no_two = int(input("the second number please :"))
    
    try :
        division = no_one / no_two

    except ZeroDivisionError: # ZeroD.. hatası varsa beni çalıştır.
        print("You can't divide by zero!...Try again.")

    else :  # Try doğruysa elseyi çalıştır.
        print("the result of the division is : ", division)

    finally :   # beni her halukarda çalıştır.
        print("thanks for using our mini divison calculator. come again!")
        break
# Out:
# thanks for using our mini divison calculator. come again!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
while True :
    try :
        no_one = int(input("the first number please :"))
        no_two = int(input("the second number please :"))
        division = no_one / no_two
# Bir önceki kod satırında no_two:string değer girince kod çalışmamıştı ama şimdi çalıştı 
# Nedeni int değer girmemiz gereken yere str girdik. buda bir hatadır.
# Ama ZeroD. hatası olmadığı için except bloğu çalışmadı.
# Kod hatalı olduğu için zaten else hiç çalışmaz.   
# ama finally her halukarda çalışır. 
    except ZeroDivisionError:
        print("You can't divide by zero!...Try again.")

    else :
        print("the result of the division is : ", division)

    finally :
        print("thanks for using our mini divison calculator. come again!")
        break
# Out:
# thanks for using our mini divison calculator. come again!

# %%
while True :
    no_one = int(input("the first number please :"))
    no_two = int(input("the second number please :"))
    
    try :
        division = no_one / no_two
        print("the result of the division is : ", division)
        break
        
    # except Exception :
    #     print("The exception that raised is :", Exception)
    #     break
# dıgıdık ne işe yarar: Execptin türünü alıp diğer satırlarda kullanmamıza yarar.
    except Exception  as dıgıdık:
        print("The exception that raised is :", dıgıdık)
        break

# %%
while True :  
    try :
        no_one = int(input("the first number please :"))
        no_two = int(input("the second number please :"))
        division = no_one / no_two
        print("the result of the division is : ", division)
        break
# numaraları hatalıda girsek bölme işleminde de hata olsa hataya göre yazdırma yapar.
    except Exception as dıgıdık :
        print("The exception that raised is :", dıgıdık)
        break
# Out:
# The exception that raised is : division by zero

# %%
try :  # body de ZeroDivisionError yok o yüzden bi sonraki except bloğu çalışır.
    x
except ZeroDivisionError :
    print("You are trying to divide by zero")
except :
    print("something else went wrong")

# %%
try :
    x
except ZeroDivisionError :
    print("You are trying to divide by zero")
except NameError :  # burayı yakaldı.
    print("the wrong is related to name error")
except :
    print("something else went wrong")

# %%
try :  # Şimdi bir hata var. 2 0'a bölünmez. o yüzden except bloğu çalıştı.
    x = 2/0
    
except ZeroDivisionError :
    print("You are trying to divide by zero")
except :
    print("something else went wrong")
# Out:
# You are trying to divide by zero

# %%
int("on") # Value error hhatası

# %%
try :
    int("on")
    
except ZeroDivisionError :
    print("You are trying to divide by zero")
except NameError :
    print("the wrong is related to name error")
except :  # value hatası digerlerinde olmadığı için bu blok çalıştı.
    print("something else went wrong")
# Out:
# something else went wrong

# %%
try :
    int("on")
    
except ZeroDivisionError :
    print("You are trying to divide by zero")
except NameError :
    print("the wrong is related to name error")
except (ValueError, TypeError): #burada yakaldı.
    print("the wrong is related to value or type error")
except :
    print("something else went wrong")
# Out:
# the wrong is related to value or type error

# %%
try :
    4 /0
    
except ArithmeticError :
    print("You are trying to divide by zero")
except NameError :
    print("the wrong is related to name error")
except (ValueError, TypeError):
    print("the wrong is related to value or type error")
except :
    print("something else went wrong")
# Out:
# You are trying to divide by zero

# %%
try :
    4 + "4"
    
except ZeroDivisionError :
    print("You are trying to divide by zero")
except NameError :
    print("the wrong is related to name error")
except (ValueError, TypeError):
    print("the wrong is related to value or type error")
except :
    print("something else went wrong")
# Out:
# the wrong is related to value or type error

# %%
fruits = ["banana", "mango", "pear", "apple", "kiwi", "grape"]

# %%
while True :
    try :
        index = int(input("pick an index number :"))
        print("your favorite fruit is", fruits[index])
        break
    except IndexError :
        print("there is no such an index. Try again!")
        
    except ValueError :
        print("you should enter integer. Try again!")
# Out:
# pick an index number :9
# there is no such an index. Try again!
# pick an index number :k7
# you should enter integer. Try again!
# pick an index number :-1
# your favorite fruit is grape

# %%
try:
  a = 10
  b = 5
  print('sonuç :', c)
except Exception as e:
  print('hata mesajı:', e)
# Out:
# hata mesajı: name 'c' is not defined

# %%
try:
  print('çocuklar nerede',"k")
except:
  print('hata mesajı')
else:  # except blogu çalışmazsa else çalışır.
  print('herşey yolunda')
# Out:
# çocuklar nerede k
# herşey yolunda

# %%
try:
  print('çocuklar nerede')
except:
  print('hata mesajı')
finally:  # mutlaka yazılır.
  print('herşey yolunda')
# Out:
# çocuklar nerede
# herşey yolunda

# %%
try:
    x = k/h
except ZeroDivisionError:
    print('Attempt to divide by zero')

except TypeError:
    print("You can only enter numbers consisting of digits, not text!!")
except Exception as hata_ne:
    print('Something else went wrong: ', hata_ne)
# Out:
# Something else went wrong:  name 'k' is not defined

# %%
x=10
y=8
assert x<y, 'X too small'  # Body False ise metni yazdırır.
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\Users\user\OneDrive\IT\PYTHON\&PYTHON\&MY_PYTHON_NOTES\06_Program Flow, Error _ Exception Handling\00_Errors_Exception_Handling.ipynb Hücre 39 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/IT/PYTHON/%26PYTHON/%26MY_PYTHON_NOTES/06_Program%20Flow%2C%20Error%20_%20Exception%20Handling/00_Errors_Exception_Handling.ipynb#X52sZmlsZQ%3D%3D?line=0'>1</a> x=10
#       <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/IT/PYTHON/%26PYTHON/%26MY_PYTHON_NOTES/06_Program%20Flow%2C%20Error%20_%20Exception%20Handling/00_Errors_Exception_Handling.ipynb#X52sZmlsZQ%3D%3D?line=1'>2</a> y=8
# ...

# %%
try:
  print(1)
  assert 2 + 2 == 5
except AssertionError:
  print(3)
except:
  print(4)
# Out:
# 1
# 3

# %%
giriş = input("Merhaba! Adın ne? ")
assert len(giriş) != 0 , "İsim bölümü boş."
print("Hoşgeldiniz.")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\Users\user\OneDrive\IT\PYTHON\&PYTHON\&MY_PYTHON_NOTES\06_Program Flow, Error _ Exception Handling\00_Errors_Exception_Handling.ipynb Hücre 41 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/IT/PYTHON/%26PYTHON/%26MY_PYTHON_NOTES/06_Program%20Flow%2C%20Error%20_%20Exception%20Handling/00_Errors_Exception_Handling.ipynb#X54sZmlsZQ%3D%3D?line=0'>1</a> giriş = input("Merhaba! Adın ne? ")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/IT/PYTHON/%26PYTHON/%26MY_PYTHON_NOTES/06_Program%20Flow%2C%20Error%20_%20Exception%20Handling/00_Errors_Exception_Handling.ipynb#X54sZmlsZQ%3D%3D?line=1'>2</a> assert len(giriş) != 0 , "İsim bölümü boş."
# ...

# %%
giriş = input("Merhaba! Adın ne? ")
if len(giriş) == 0:
    raise AssertionError("İsim bölümü boş.")
print("Hoşgeldiniz.")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\Users\user\OneDrive\IT\PYTHON\&PYTHON\&MY_PYTHON_NOTES\06_Program Flow, Error _ Exception Handling\00_Errors_Exception_Handling.ipynb Hücre 42 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/IT/PYTHON/%26PYTHON/%26MY_PYTHON_NOTES/06_Program%20Flow%2C%20Error%20_%20Exception%20Handling/00_Errors_Exception_Handling.ipynb#X55sZmlsZQ%3D%3D?line=0'>1</a> giriş = input("Merhaba! Adın ne? ")
#       <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/IT/PYTHON/%26PYTHON/%26MY_PYTHON_NOTES/06_Program%20Flow%2C%20Error%20_%20Exception%20Handling/00_Errors_Exception_Handling.ipynb#X55sZmlsZQ%3D%3D?line=1'>2</a> if len(giriş) == 0:
# ...

# %%
valid = False
while not valid:
 try:
  n=int(input("Enter a number"))
  while n%2==0:
   print("Bye")
  valid = True
 except ValueError:
  print("Invalid")

# %%
bölünen = int(input("bölünecek sayı: "))
# Görüldüğü gibi raise metodu try: except bloğu dışında da kullanılabiliyor.
if bölünen == 23:
    raise Exception("Bu programda 23 sayısını görmek istemiyorum!")

# %%
tr_karakter = "şçğüöıİ"

parola = input("Parolanız: ")

for i in parola:
    if i in tr_karakter:
        raise TypeError("Parolada Türkçe karakter kullanılamaz!")
    # else:
    #     pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\user\OneDrive\IT\PYTHON\&PYTHON\&MY_PYTHON_NOTES\06_Program Flow, Error _ Exception Handling\00_Errors_Exception_Handling.ipynb Hücre 45 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/IT/PYTHON/%26PYTHON/%26MY_PYTHON_NOTES/06_Program%20Flow%2C%20Error%20_%20Exception%20Handling/00_Errors_Exception_Handling.ipynb#X61sZmlsZQ%3D%3D?line=4'>5</a> for i in parola:
#       <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/IT/PYTHON/%26PYTHON/%26MY_PYTHON_NOTES/06_Program%20Flow%2C%20Error%20_%20Exception%20Handling/00_Errors_Exception_Handling.ipynb#X61sZmlsZQ%3D%3D?line=5'>6</a>     if i in tr_karakter:
# ...

# %%
try:
    bölünen = int(input("bölünecek sayı: "))
    bölen = int(input("bölen sayı: "))
    print(bölünen/bölen)
except ZeroDivisionError:
    print("bir sayıyı 0'a bölemezsiniz")
    raise
# Out:
# bölünecek sayı: 6
# bölen sayı: k
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-5d23a865d26c> in <module>()
#       1 try:
#       2     bölünen = int(input("bölünecek sayı: "))
# ----> 3     bölen = int(input("bölen sayı: "))
#       4     print(bölünen/bölen)
#       5 except ZeroDivisionError:
#
# ValueError: invalid literal for int() with base 10: 'k'

# %%
try:
    bölünen = int(input("bölünecek sayı: "))
    bölen = int(input("bölen sayı: "))
    print(bölünen/bölen)
except ValueError:
    print("bir sayıyı k'a bölemezsiniz")
    # raise
# Out:
# bölünecek sayı: 6
# bölen sayı: k
# bir sayıyı k'a bölemezsiniz

# %%
nums = [55, 44, 33, 22, 11, 4]
if all([i>5 for i in nums]):
  print("All larger than 5")
if any([i%2 == 0 for i in nums]):
  print('at least one is even')
for v in enumerate(nums, 1):
  print(v)
# Out:
# at least one is even
# (1, 55)
# (2, 44)
# (3, 33)
# (4, 22)
# (5, 11)
# (6, 4)

# %%
nums = [55, 44, 33, 22, 11, 4]
a= [i>5 for i in nums]
# all([i>5 for i in nums])
a
# Out:
# [True, True, True, True, True, False]

# %%
bool([])
# Out:
# False

# %%
all([])
# Out:
# True

# %%
any([4])
# Any kelimesi İngilizcede ‘herhangi bir’ anlamına gelir. İşte any() fonksiyonunun görevi de, bir dizi içindeki bütün değerlerden en az biri True ise True çıktısı vermektir.
# Out:
# True
